# %% [markdown]
# <a href="https://colab.research.google.com/github/JosePimienta/utb_agricultura/blob/main/Agricultura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importar librerias

# %%
# Importar librerias
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Leer csv

# %%
df = pd.read_csv('/content/drive/MyDrive/BOOTCAMP UTB/Agricultura_y_Desarrollo_Rural.csv')
df
# Out:
#       CodDpto Departamento  CodMunicipio Municipio          Cultivo  Periodo  \
# 0          13      Bolívar         13006      Achí         Aguacate     2016
# 1          13      Bolívar         13006      Achí          AHUYAMA     2016
# 2          13      Bolívar         13006      Achí          AHUYAMA     2016
# 3          13      Bolívar         13006      Achí      Arroz Riego     2016
# 4          13      Bolívar         13006      Achí      Arroz Riego     2016
# ...       ...          ...           ...       ...              ...      ...
# 2630       13      Bolívar         13894  Zambrano           Tabaco     2020
# 2631       13      Bolívar         13894  Zambrano          Patilla     2020
# 2632       13      Bolívar         13894  Zambrano            Melón     2020
# 2633       13      Bolívar         13894  Zambrano             Yuca     2020
# 2634       13      Bolívar         13894  Zambrano  Palma de aceite     2020
#
# ...

# %%
# Tabla Cruzada
tabla_cruzada = pd.crosstab(df['Municipio'], df['Cultivo'])
tabla_cruzada
# Out:
# Cultivo                 120  21  400  AHUYAMA  Achiote  Aguacate  Ahuyama  \
# Municipio
# Achí                      0   0    0        2        0         5        8
# Altos Del Rosario         0   0    0        0        0         0        0
# Altos del Rosario         0   0    0        0        0         0        0
# Arenal                    0   0    0        0        0         0        0
# Arjona                    0   0    0        0        0         0        0
# ...                     ...  ..  ...      ...      ...       ...      ...
# Tiquisio (Puerto Rico)    0   0    0        0        0         0        0
# Turbaco                   0   0    0        0        0         0        0
# Turbana                   0   0    0        0        0         0        0
# Villanueva                0   1    0        0        0         0        0
# Zambrano                  0   0    0        0        0         0        1
#
# Cultivo                 Aji  Aji Dulce  Aji Tabasco  ...  Tabaco  \
# ...

# %%
#Verificar carga de dataframe
print(df.head())
# Out:
#    CodDpto Departamento  CodMunicipio Municipio      Cultivo  Periodo  \
# 0       13      Bolívar         13006      Achí     Aguacate     2016
# 1       13      Bolívar         13006      Achí      AHUYAMA     2016
# 2       13      Bolívar         13006      Achí      AHUYAMA     2016
# 3       13      Bolívar         13006      Achí  Arroz Riego     2016
# 4       13      Bolívar         13006      Achí  Arroz Riego     2016
#
#    Área Sembrada\n(ha)  Área Cosechada\n(ha)  Producción\n(t)  \
# 0                 80.0                  80.0            960.0
# 1                 15.0                  15.0            225.0
# 2                 50.0                  25.0            300.0
# 3                861.0                 600.0           2700.0
# 4                600.0                 600.0           3000.0
#
#    Rendimiento\n(t/ha)
# 0                 12.0
# 1                 15.0
# 2                 12.0
# 3                  4.5
# 4                  5.0

# %%
#Mostrar información del dataset
print('\nInformacion dataset')
print(df.info())
# Out:
# Informacion dataset
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2635 entries, 0 to 2634
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CodDpto              2635 non-null   int64
#  1   Departamento         2635 non-null   object
#  2   CodMunicipio         2635 non-null   int64
#  3   Municipio            2635 non-null   object
#  4   Cultivo              2635 non-null   object
#  5   Periodo              2635 non-null   int64
#  6   Área Sembrada
# (ha)   2635 non-null   float64
#  7   Área Cosechada
# (ha)  2626 non-null   float64
#  8   Producción
# (t)       2626 non-null   float64
#  9   Rendimiento
# (t/ha)   2628 non-null   float64
# dtypes: float64(4), int64(3), object(3)
# memory usage: 206.0+ KB
# None

# %%
#Revisar estadisticas descriptivas
print('\nEstadistica datos numéricos')
print(df.describe())
print('\nEstadistica datos categóricos')
print(df.describe(include='object'))
# Out:
# Estadistica datos numéricos
#        CodDpto  CodMunicipio      Periodo  Área Sembrada\n(ha)  \
# count   2635.0   2635.000000  2635.000000          2635.000000
# mean      13.0  13465.999241  2018.126376           407.069070
# std        0.0    268.284911     1.417286           941.486341
# min       13.0  13001.000000  2016.000000             0.000000
# 25%       13.0  13244.000000  2017.000000            20.000000
# 50%       13.0  13473.000000  2018.000000           110.000000
# 75%       13.0  13670.000000  2019.000000           400.000000
# max       13.0  13894.000000  2020.000000         12000.000000
#
#        Área Cosechada\n(ha)  Producción\n(t)  Rendimiento\n(t/ha)
# count           2626.000000      2626.000000          2628.000000
# mean             352.875666      1822.637860             6.552059
# std              818.522947      7332.167304             8.572230
# min                0.000000         0.000000             0.000000
# ...

# %%
#Grafico de barras apiladas
fig,ax =plt.subplots(figsize=(16,10))
tabla_cruzada.plot(kind='bar', stacked=True, ax=ax)
ax.legend(title='Cultivos', bbox_to_anchor=(1.05, 1), loc='upper left', ncol=3)
plt.show()

# %% [markdown]
# Limpiar datos (Colocar en minusculas)

# %%
df['Municipio'] = df['Municipio'].str.lower().str.strip()
df['Cultivo'] = df['Cultivo'].str.lower().str.strip()

# %%
# !pip install unidecode
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 4.1 MB/s eta 0:00:00
# ...

# %%
import unidecode

# %%
df['Municipio'] = df['Municipio'].apply(unidecode.unidecode)
df['Cultivo'] = df['Cultivo'].apply(unidecode.unidecode)

# %%
# Tabla Cruzada
tabla_cruzada = pd.crosstab(df['Municipio'], df['Cultivo'])
tabla_cruzada
# Out:
# Cultivo                 120  21  400  achiote  aguacate  ahuyama  aji  \
# Municipio
# achi                      0   0    0        0         5       10    0
# altos del rosario         0   0    0        0         0        0    0
# arenal                    0   0    0        0         0        0    0
# arjona                    0   0    0        0         0        0    0
# arroyohondo               0   0    0        0         0        0    0
# barranco de loba          0   0    0        0         5        2    0
# calamar                   0   0    0        0         0        3    6
# cantagallo                0   0    1        0         0        0    0
# cartagena de indias       0   0    0        0         0        0    3
# cicuco                    0   0    0        0         0        2    1
# clemencia                 0   0    0        0         0        0    0
# cordoba                   0   0    0        0         0        2    0
# ...

# %%
#Grafico de barras apiladas
fig,ax = plt.subplots(figsize=(16,10))
tabla_cruzada.plot(kind='bar', stacked=True, ax=ax)
ax.legend(title='Cultivos', bbox_to_anchor=(1.05, 1), loc='upper left', ncol=3)
plt.show()

# %%
df['Municipio']=df['Municipio'].replace({'tiquisio (puerto rico':'tiquisio (puerto rico)'})
df['Municipio']=df['Municipio'].replace({'rioviejo':'rio viejo'})

# %%
# Tabla Cruzada
tabla_cruzada = pd.crosstab(df['Municipio'], df['Cultivo'])
tabla_cruzada
# Out:
# Cultivo                 120  21  400  achiote  aguacate  ahuyama  aji  \
# Municipio
# achi                      0   0    0        0         5       10    0
# altos del rosario         0   0    0        0         0        0    0
# arenal                    0   0    0        0         0        0    0
# arjona                    0   0    0        0         0        0    0
# arroyohondo               0   0    0        0         0        0    0
# barranco de loba          0   0    0        0         5        2    0
# calamar                   0   0    0        0         0        3    6
# cantagallo                0   0    1        0         0        0    0
# cartagena de indias       0   0    0        0         0        0    3
# cicuco                    0   0    0        0         0        2    1
# clemencia                 0   0    0        0         0        0    0
# cordoba                   0   0    0        0         0        2    0
# ...

# %%
#Grafico de barras apiladas
fig,ax = plt.subplots(figsize=(16,10))
tabla_cruzada.plot(kind='bar', stacked=True, ax=ax)
ax.legend(title='Cultivos', bbox_to_anchor=(1.05, 1), loc='upper left', ncol=3)
plt.show()

# %% [markdown]
# Revisar cultivos con nombres: 120, 21 y 400

# %%
rev_cultivo = ['120', '21', '400']
print(df[df['Cultivo'].isin(rev_cultivo)])
# Out:
#      CodDpto Departamento  CodMunicipio       Municipio Cultivo  Periodo  \
# 530       13      Bolívar         13160      cantagallo     400     2017
# 865       13      Bolívar         13673  santa catalina     120     2017
# 969       13      Bolívar         13873      villanueva      21     2017
#
#      Área Sembrada\n(ha)  Área Cosechada\n(ha)  Producción\n(t)  \
# 530                  4.0                   NaN              NaN
# 865                  0.0                   NaN              NaN
# 969                342.0                   NaN              NaN
#
#      Rendimiento\n(t/ha)
# 530                  NaN
# 865                  NaN
# 969                  NaN

# %%
#Copia de df original
df_original = df.copy()

# %%
df = df[~df['Cultivo'].isin(rev_cultivo)]

# %%
# Tabla Cruzada
tabla_cruzada = pd.crosstab(df['Cultivo'], df['Municipio'])
tabla_cruzada
# Out:
# Municipio        achi  altos del rosario  arenal  arjona  arroyohondo  \
# Cultivo
# achiote             0                  0       0       0            0
# aguacate            5                  0       0       0            0
# ahuyama            10                  0       0       0            0
# aji                 0                  0       0       0            0
# aji dulce           0                  0       0       0            0
# ...               ...                ...     ...     ...          ...
# tabaco rubio        0                  0       0       0            0
# tomate              0                  0       0       0            0
# yuca                7                  7       6       7            5
# yuca industrial     0                  0       0       0            0
# zapote              5                  0       0       0            0
#
# Municipio        barranco de loba  calamar  cantagallo  cartagena de indias  \
# Cultivo
# ...

# %%
#Grafico de barras apiladas
fig,ax = plt.subplots(figsize=(16,10))
tabla_cruzada.plot(kind='bar', stacked=True, ax=ax)
ax.legend(title='Municipios', bbox_to_anchor=(1.05, 1), loc='upper left', ncol=3)
plt.show()
